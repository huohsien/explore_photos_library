# %%
# ============================================================
# Section 1: Imports and Photos Library paths
# ============================================================

import osxphotos

from photos_inventory import *


USE_INVENTORY_CACHE = True


PHOTOS_LIBRARY_PATHS = {
    "backup_20250317": "/Volumes/NEW-PRO-G40--20250315/Photos Library-iCloud-20250317（iCloud 20250325崩潰前最後的備份）--opened by macOS Sequoia on 20260604.photoslibrary",
    "current_default": "/Users/huohsien/Pictures/Photos Library.photoslibrary",
    "test": "/Users/huohsien/Pictures/test.photoslibrary",
}

# %%
# ============================================================
# Section 2: Load or build inventories
# ============================================================


def load_or_build_inventory(library_key):
    library_path = PHOTOS_LIBRARY_PATHS[library_key]

    if USE_INVENTORY_CACHE:
        print("=" * 80)
        print(f"Load inventory cache: {library_key}")
        print("=" * 80)

        try:
            inventory = load_inventory_cache(library_key)
            return inventory
        except FileNotFoundError:
            print(f"Cache not found for {library_key}. Build inventory instead.")
            print()

    print("=" * 80)
    print(f"Build inventory: {library_key}")
    print("=" * 80)

    osx_assets = osxphotos.PhotosDB(library_path).photos()
    print(f"{library_key} osx asset count:", len(osx_assets))

    inventory = build_inventory(osx_assets)

    print()
    print(f"{library_key} inventory summary")
    print("-" * 80)
    print_inventory_summary(inventory)

    save_inventory_cache(inventory, library_key)

    return inventory


inventory_backup = load_or_build_inventory("backup_20250317")

print()

inventory_snapshot = load_or_build_inventory("current_default")
# Out:
# ================================================================================
# Load inventory cache: backup_20250317
# ================================================================================
# loaded inventory cache: data/inventory_cache/backup_20250317.inventory.pkl.gz
# elapsed seconds: 0.5
# inventory assets: 71599
# inventory albums: 5172
# inventory folders: 35
# movies: 6240
# hidden: 0
# favorites: 699
# descriptions: 727
# keywords: 23758
#
# ================================================================================
# Load inventory cache: current_default
# ================================================================================
# loaded inventory cache: data/inventory_cache/current_default.inventory.pkl.gz
# elapsed seconds: 0.68
# inventory assets: 94739
# inventory albums: 5956
# inventory folders: 33
# movies: 7406
# hidden: 1
# favorites: 768
# descriptions: 2293
# keywords: 27529

# %%
hidden_assets = [asset for asset in inventory_backup["assets"] if asset["hidden"] is True]

print("hidden asset count:", len(hidden_assets))
hidden_assets[:5]
# Out:
# hidden asset count: 0
# []

# %%
# ============================================================
# Dump all folders
# ============================================================

folders = inventory_backup["folders"]

print("folder count:", len(folders))
print()

for folder_uuid, folder in sorted(
    folders.items(),
    key=lambda item: item[1]["path"]
):
    print("uuid:", folder_uuid)
    print("title:", folder["title"])
    print("path:", folder["path"])
    print()
# Out:
# folder count: 35
#
# uuid: DB891065-9DEE-49BB-9BDB-F061AE5AA6A9
# title: 4G（5G)上網iPhone 12 Pro在溫州街家中測試速度（後面加了捷運跟瑜珈教室5G的測試資料）
# path: 4G（5G)上網iPhone 12 Pro在溫州街家中測試速度（後面加了捷運跟瑜珈教室5G的測試資料）
#
# uuid: CF894E20-CD0E-4FC1-86C4-545F1A3C10F9
# title: Empty Albums
# path: Empty Albums
#
# uuid: 60820193-D851-499C-89FB-4D57EDC8FCFE
# title: HIDE
# path: HIDE
#
# uuid: 12696767-5E97-469E-AC42-1B9E5A501451
# title: HIDE_UGLY
# path: HIDE_UGLY
#
# uuid: 9A76E769-36B9-4FC4-8831-7B2FE9E68058
# title: Insta360
# path: Insta360
#
# uuid: 5D8A689A-82C2-4A1D-959B-35F00BFD370B
# title: NSFW
# path: NSFW
#
# uuid: 9EAF4AB8-BBA6-4276-AD20-C0C359AC82CA
# title: AV
# path: NSFW/AV
#
# uuid: 905C95BA-525D-48F6-94C3-22B94BEF2AB2
# title: SPY_PRETTY_GIRLS
# path: NSFW/SPY_PRETTY_GIRLS
#
# uuid: DCBF0102-E373-4F52-9F39-35E317142BF7
# title: Yoga Practice Sequences
# path: Yoga Practice Sequences
#
# uuid: 9378FBB3-D368-4A03-B4B4-1BB735AA9144
# title: 信用卡帳單
# path: 信用卡帳單
#
# uuid: 616957A4-B5C0-4565-9EAB-C217F00DFA9F
# title: 出國旅遊
# path: 出國旅遊
#
# uuid: 824CFE3F-C24D-4FFE-A51C-6008237CF061
# title: #北海道便宜團 2024年9月17~9月21日
# path: 出國旅遊/#北海道便宜團 2024年9月17~9月21日
#
# uuid: 0C57F333-8B43-4851-9A0D-E92F758DB8B8
# title: 去澳洲參加1995年國際物理奧林匹亞競賽
# path: 去澳洲參加1995年國際物理奧林匹亞競賽
#
# uuid: 24FC773D-CD66-4AEB-8966-6048518484B5
# title: 我
# path: 我
#
# uuid: 846B865E-E5B6-4602-AC60-02181466F5E3
# title: 皮膚異常狀況
# path: 我/皮膚異常狀況
#
# uuid: 64E4452D-A3E3-4B8B-8DEB-91C48CA7BC60
# title: 我小時候的照片（翻拍）
# path: 我小時候的照片（翻拍）
#
# uuid: CB3915A2-EA18-4706-8CDD-7A0043D4A477
# title: 文件
# path: 文件
#
# uuid: 25AC615F-4085-42FD-B27A-F8B478F047E8
# title: 新聞
# path: 新聞
#
# uuid: B7715DAD-70EE-49FE-9CAC-F9D65F587F6B
# title: 有趣的東西--雜七雜八
# path: 有趣的東西--雜七雜八
#
# uuid: 7B4D23F9-FAAF-4E7B-836C-9E4444CD5742
# title: 業障江家
# path: 業障江家
#
# uuid: DB70D48E-56A6-4337-83E7-A534FA5B713F
# title: 林欒菲
# path: 業障江家/林欒菲
#
# uuid: 89AA323F-7C44-434F-B93C-C4AC48BAB68F
# title: 業障江品瑩
# path: 業障江家/業障江品瑩
#
# uuid: 39AAA8D3-A18A-42B2-AB24-46B78C6EE79C
# title: 業障陳鳳尾
# path: 業障江家/業障陳鳳尾
#
# uuid: 02526F6E-31FB-4F3C-AADF-BA418767C595
# title: 股票
# path: 股票
#
# uuid: DE9CC2C7-D464-42E2-9518-74DB82C00E2E
# title: #YouTube股市名嘴 #預測 #報明牌
# path: 股票/#YouTube股市名嘴 #預測 #報明牌
#
# uuid: E896C603-101A-449F-953A-D0F814CA8F9E
# title: #台股 #重要記事本
# path: 股票/#台股 #重要記事本
#
# uuid: 7888DD80-FA15-44DB-B680-549F1C726416
# title: 能量冥想＋脈輪瑜伽 線上課程 by Corey
# path: 能量冥想＋脈輪瑜伽 線上課程 by Corey
#
# uuid: 821F8584-5529-4890-BF5D-0766F2B162E6
# title: 藏傳佛教
# path: 藏傳佛教
#
# uuid: 60C2CA72-8590-40B1-9503-BC61C54827A2
# title: 送貨
# path: 送貨
#
# uuid: 8A297BB2-BB10-4BA6-B0EB-439FE48CE5D1
# title: 重要文件（隱藏）
# path: 重要文件（隱藏）
#
# uuid: 7E6A7829-F9A9-49D7-AA7E-4F5C664F2301
# title: 銀行：換匯轉帳
# path: 銀行：換匯轉帳
#
# uuid: 1A62E340-4AC2-4923-B873-B34B70B4FE1F
# title: 開箱
# path: 開箱
#
# uuid: DA2AD619-2C50-44A5-9C2F-D6069441F29D
# title: 電器壞掉（不修）
# path: 電器壞掉（不修）
#
# uuid: ABCCCC5A-262A-438E-87FD-EA8D3D089E54
# title: 點外送
# path: 電器壞掉（不修）/點外送
#
# uuid: 3D96A6E6-787B-4712-8072-22E595A7E37D
# title: 電器故障與維修
# path: 電器故障與維修

# %%
# ============================================================
# Find folder by title keyword
# ============================================================

target_folder_title = "4G（5G)上網iPhone 12 Pro在溫州街家中測試速度（後面加了捷運跟瑜珈教室5G的測試資料）"

matched_folders = find_folders_by_title_keyword(
    inventory_backup,
    target_folder_title,
)

print("matched folder count:", len(matched_folders))
print()

for folder in matched_folders:
    print("folder uuid:", folder["uuid"])
    print("folder title:", folder["title"])
    print("folder path:", folder["path"])
    print()
# Out:
# matched folder count: 1
#
# folder uuid: DB891065-9DEE-49BB-9BDB-F061AE5AA6A9
# folder title: 4G（5G)上網iPhone 12 Pro在溫州街家中測試速度（後面加了捷運跟瑜珈教室5G的測試資料）
# folder path: 4G（5G)上網iPhone 12 Pro在溫州街家中測試速度（後面加了捷運跟瑜珈教室5G的測試資料）

# %%
# ============================================================
# List albums under matched_folders[0]
# ============================================================

folder = matched_folders[0]

print("Target folder")
print("-------------")
print("folder title:", folder["title"])
print("folder path:", folder["path"])
print("folder uuid:", folder["uuid"])
print()

matched_albums = find_albums_under_folder(
    inventory_backup,
    folder,
)

print("album count:", len(matched_albums))
print()

for album in matched_albums:
    print(album["title"])
# Out:
# Target folder
# -------------
# folder title: 4G（5G)上網iPhone 12 Pro在溫州街家中測試速度（後面加了捷運跟瑜珈教室5G的測試資料）
# folder path: 4G（5G)上網iPhone 12 Pro在溫州街家中測試速度（後面加了捷運跟瑜珈教室5G的測試資料）
# folder uuid: DB891065-9DEE-49BB-9BDB-F061AE5AA6A9
#
# album count: 22
#
# 中華 4G 凌晨五點 家中書房書桌前
# 中華 5G 傍晚 Yoga Edition 5F到6F樓梯間
# 中華 5G 傍晚 Yoga Edition 6F教室外面飲水機旁邊
# 中華 5G 傍晚 捷運 中正紀念堂-》小南門 車廂內
# 中華 5G 傍晚 捷運 台北車站剛離站車廂內
# 中華 5G 傍晚 捷運 忠孝敦化捷運站月台上
# 中華 5G 傍晚 捷運 西門剛離站往台北車站 車廂內
# 中華 5G 傍晚 捷運 西門快到站 車廂內
# 中華 5G 傍晚 捷運 西門站月台
# 中華 5G 凌晨五點 家中書房書桌前（居然收到5G訊號而且很強！速度居然破表的快！）後來發現不穩定一下有5G，一下子又只有4G！
# 中華 5G 半夜12點鐘 家中書房書桌前 有時居然收到5G訊號而且很強！速度居然破表的快！但不穩定。一下有5G，一下子又只有4G！然後如果熱點分享居然也可以超過100Mbps
# 中華 5G 晚上八點  羅曼羅蘭？（辛亥路五段93號）速度超級快！
# 中華 5G 晚上八點 捷運 台北車站往西門剛離站車廂內
# 中華 5G 晚上八點 捷運 台電大樓站月台
# 中華 5G 晚上八點 捷運 小南門站月台
# 中華 5G/4G（比較） 晚上八點  出了台電大樓站捷運站的路口
# 中華 下午兩點半到三點
# 中華 傍晚 5G試用卡（是月租費2399的速度，幾乎沒有參考價值。服務人員還說的一副理所當然，台灣現在年輕人的想法很詭異…這是代溝吧）
# 中華 傍晚4:30
# 中華 晚上10:30
# 遠傳 下午兩點半
# 遠傳 晚上10:30

# %%
# ============================================================
# Check whether old folder's albums still exist in snapshot
# ============================================================

old_album_titles = [
    album["title"]
    for album in matched_albums
]

found_titles, missing_titles = check_album_titles_exist_in_inventory(
    album_titles=old_album_titles,
    inventory=inventory_snapshot,
)

print("old album count:", len(old_album_titles))
print("found in snapshot:", len(found_titles))
print("missing in snapshot:", len(missing_titles))
print()

print("Missing albums")
print("--------------")
for title in missing_titles:
    print(title)

print()
print("Found albums")
print("------------")
for title in found_titles:
    print(title)
# Out:
# old album count: 22
# found in snapshot: 22
# missing in snapshot: 0
#
# Missing albums
# --------------
#
# Found albums
# ------------
# 中華 4G 凌晨五點 家中書房書桌前
# 中華 5G 傍晚 Yoga Edition 5F到6F樓梯間
# 中華 5G 傍晚 Yoga Edition 6F教室外面飲水機旁邊
# 中華 5G 傍晚 捷運 中正紀念堂-》小南門 車廂內
# 中華 5G 傍晚 捷運 台北車站剛離站車廂內
# 中華 5G 傍晚 捷運 忠孝敦化捷運站月台上
# 中華 5G 傍晚 捷運 西門剛離站往台北車站 車廂內
# 中華 5G 傍晚 捷運 西門快到站 車廂內
# 中華 5G 傍晚 捷運 西門站月台
# 中華 5G 凌晨五點 家中書房書桌前（居然收到5G訊號而且很強！速度居然破表的快！）後來發現不穩定一下有5G，一下子又只有4G！
# 中華 5G 半夜12點鐘 家中書房書桌前 有時居然收到5G訊號而且很強！速度居然破表的快！但不穩定。一下有5G，一下子又只有4G！然後如果熱點分享居然也可以超過100Mbps
# 中華 5G 晚上八點  羅曼羅蘭？（辛亥路五段93號）速度超級快！
# 中華 5G 晚上八點 捷運 台北車站往西門剛離站車廂內
# 中華 5G 晚上八點 捷運 台電大樓站月台
# 中華 5G 晚上八點 捷運 小南門站月台
# 中華 5G/4G（比較） 晚上八點  出了台電大樓站捷運站的路口
# 中華 下午兩點半到三點
# 中華 傍晚 5G試用卡（是月租費2399的速度，幾乎沒有參考價值。服務人員還說的一副理所當然，台灣現在年輕人的想法很詭異…這是代溝吧）
# 中華 傍晚4:30
# 中華 晚上10:30
# 遠傳 下午兩點半
# 遠傳 晚上10:30

# %%
find_folders_by_title_keyword(inventory_backup,"外送")
# Out:
# [{'uuid': 'ABCCCC5A-262A-438E-87FD-EA8D3D089E54',
#   'title': '點外送',
#   'path': '電器壞掉（不修）/點外送'}]

# %%
# ============================================================
# Test 1: Find assets with exact HIDE keyword
# ============================================================

hide_keyword_assets = [
    asset
    for asset in inventory_snapshot["assets"]
    if "HIDE" in tuple(asset["keywords"] or ())
]

print("HIDE keyword asset count:", len(hide_keyword_assets))
hide_keyword_assets[:5]
# Out:
# HIDE keyword asset count: 27522
# [{'uuid': '85F8DB3E-0378-4B34-9894-166D89E2CFE6',
#   'filename': '85F8DB3E-0378-4B34-9894-166D89E2CFE6.jpeg',
#   'original_filename': 'IMG_0336.JPG',
#   'path': '/Users/huohsien/Pictures/Photos Library.photoslibrary/originals/8/85F8DB3E-0378-4B34-9894-166D89E2CFE6.jpeg',
#   'asset_scope': 'NORMAL_ORIGINALS',
#   'is_movie': False,
#   'date': '2018-04-20T12:56:55.407826+08:00',
#   'date_added': '2018-04-20T12:56:55.410903+08:00',
#   'date_modified': None,
#   'description': None,
#   'keywords': ('HIDE',),
#   'favorite': False,
#   'hidden': False,
#   'hasadjustments': False,
#   'adjustment_type': 0,
#   'external_edit': False,
#   'uti_edited': None,
#   'path_edited': None,
#   'path_edited_live_photo': None,
#   'edited_duration_seconds': None,
#   'latitude': None,
#   'longitude': None,
#   'location': (None, None),
#   'place': None,
#   'is_live_photo': False,
#   'path_live_photo': None,
#   'albums': {'58AB8EBD-412E-442A-85B9-45382FE7B501': {'uuid': '58AB8EBD-412E-442A-85B9-45382FE7B501',
#     'title': 'Girls-3',
#     'folders': {'1002E254-8A71-4586-967B-C9E8EEF38809': {'uuid': '1002E254-8A71-4586-967B-C9E8EEF38809',
#       'title': 'HIDE',
#       'path': 'HIDE'}}}},
#   'folders': {'1002E254-8A71-4586-967B-C9E8EEF38809': {'uuid': '1002E254-8A71-4586-967B-C9E8EEF38809',
#     'title': 'HIDE',
#     'path': 'HIDE'}}},
#  {'uuid': '6B979630-BEB0-47E5-99DD-001B3135B0CF',
#   'filename': '6B979630-BEB0-47E5-99DD-001B3135B0CF.mp4',
#   'original_filename': 'tmp_v4738117743818912152.mp4',
#   'path': '/Users/huohsien/Pictures/Photos Library.photoslibrary/originals/6/6B979630-BEB0-47E5-99DD-001B3135B0CF.mp4',
#   'asset_scope': 'NORMAL_ORIGINALS',
#   'is_movie': True,
#   'date': '2019-04-07T17:18:56.607665+08:00',
#   'date_added': '2019-04-07T17:19:03.012136+08:00',
#   'date_modified': None,
#   'description': None,
#   'keywords': ('HIDE',),
#   'favorite': False,
#   'hidden': False,
#   'hasadjustments': False,
#   'adjustment_type': 0,
#   'external_edit': False,
#   'uti_edited': None,
#   'path_edited': None,
#   'path_edited_live_photo': None,
#   'edited_duration_seconds': None,
#   'latitude': None,
#   'longitude': None,
#   'location': (None, None),
#   'place': None,
#   'is_live_photo': False,
#   'path_live_photo': None,
#   'albums': {'336F1CA5-3BB2-4C7F-8155-816821327AA8': {'uuid': '336F1CA5-3BB2-4C7F-8155-816821327AA8',
#     'title': '身材修長年輕美乳大奶妹 乳暈乳頭小顏色好形狀漂亮又大的像木瓜 只有小腹一點點贅肉，說不定是真奶',
#     'folders': {'1002E254-8A71-4586-967B-C9E8EEF38809': {'uuid': '1002E254-8A71-4586-967B-C9E8EEF38809',
#       'title': 'HIDE',
#       'path': 'HIDE'}}}},
#   'folders': {'1002E254-8A71-4586-967B-C9E8EEF38809': {'uuid': '1002E254-8A71-4586-967B-C9E8EEF38809',
#     'title': 'HIDE',
#     'path': 'HIDE'}}},
#  {'uuid': '53CFABC2-F291-4FE6-B59A-63C579CF8BF5',
#   'filename': '53CFABC2-F291-4FE6-B59A-63C579CF8BF5.png',
#   'original_filename': 'IMG_3346.PNG',
#   'path': '/Users/huohsien/Pictures/Photos Library.photoslibrary/originals/5/53CFABC2-F291-4FE6-B59A-63C579CF8BF5.png',
#   'asset_scope': 'NORMAL_ORIGINALS',
#   'is_movie': False,
#   'date': '2023-09-21T18:03:59+08:00',
#   'date_added': '2023-09-21T18:03:59.766279+08:00',
#   'date_modified': '2023-09-21T18:04:08.324444+08:00',
#   'description': None,
#   'keywords': ('HIDE',),
#   'favorite': False,
#   'hidden': False,
#   'hasadjustments': True,
#   'adjustment_type': 2,
#   'external_edit': False,
#   'uti_edited': 'public.jpeg',
#   'path_edited': '/Users/huohsien/Pictures/Photos Library.photoslibrary/resources/renders/5/53CFABC2-F291-4FE6-B59A-63C579CF8BF5_1_201_a.jpeg',
#   'path_edited_live_photo': None,
#   'edited_duration_seconds': None,
#   'latitude': None,
#   'longitude': None,
#   'location': (None, None),
#   'place': None,
#   'is_live_photo': False,
#   'path_live_photo': None,
#   'albums': {'55D0EC87-5B3F-4E5E-9641-15DBB64ACDA8': {'uuid': '55D0EC87-5B3F-4E5E-9641-15DBB64ACDA8',
#     'title': '（隱藏內容）2023年9月21日 到如來買素食第一次看到年輕可愛的小妹妹。讓我獸性大發的那種！身上穿著寵物店的制服，耳朵上戴的東西有可能是助聽器也可能是耳機！然後我查到 「金吉利寵物精品店」在汀州路三段100號 剛好就是他離開的方向！受不了就趕快去那間店逛一逛，星期四下午他應該有上班。他們是早上10:30開到晚上12點，所以現在去如來買東西吃，應該會上到12點！？',
#     'folders': {'1002E254-8A71-4586-967B-C9E8EEF38809': {'uuid': '1002E254-8A71-4586-967B-C9E8EEF38809',
#       'title': 'HIDE',
#       'path': 'HIDE'}}}},
#   'folders': {'1002E254-8A71-4586-967B-C9E8EEF38809': {'uuid': '1002E254-8A71-4586-967B-C9E8EEF38809',
#     'title': 'HIDE',
#     'path': 'HIDE'}}},
#  {'uuid': '41446327-2374-4ECF-9F89-B5D6456A6DA6',
#   'filename': '41446327-2374-4ECF-9F89-B5D6456A6DA6.png',
#   'original_filename': 'IMG_1576.PNG',
#   'path': '/Users/huohsien/Pictures/Photos Library.photoslibrary/originals/4/41446327-2374-4ECF-9F89-B5D6456A6DA6.png',
#   'asset_scope': 'NORMAL_ORIGINALS',
#   'is_movie': False,
#   'date': '2019-04-25T08:41:26+08:00',
#   'date_added': '2019-04-25T08:41:26.536572+08:00',
#   'date_modified': None,
#   'description': None,
#   'keywords': ('HIDE',),
#   'favorite': False,
#   'hidden': False,
#   'hasadjustments': False,
#   'adjustment_type': 0,
#   'external_edit': False,
#   'uti_edited': None,
#   'path_edited': None,
#   'path_edited_live_photo': None,
#   'edited_duration_seconds': None,
#   'latitude': None,
#   'longitude': None,
#   'location': (None, None),
#   'place': None,
#   'is_live_photo': False,
#   'path_live_photo': None,
#   'albums': {'A7CDAAAE-AD38-4414-B7E5-5FDCF2ADFA1C': {'uuid': 'A7CDAAAE-AD38-4414-B7E5-5FDCF2ADFA1C',
#     'title': '妖狐 girls',
#     'folders': {'1002E254-8A71-4586-967B-C9E8EEF38809': {'uuid': '1002E254-8A71-4586-967B-C9E8EEF38809',
#       'title': 'HIDE',
#       'path': 'HIDE'}}}},
#   'folders': {'1002E254-8A71-4586-967B-C9E8EEF38809': {'uuid': '1002E254-8A71-4586-967B-C9E8EEF38809',
#     'title': 'HIDE',
#     'path': 'HIDE'}}},
#  {'uuid': 'BD6F9E12-C36D-487B-A8C0-7E6F1823AECB',
#   'filename': 'BD6F9E12-C36D-487B-A8C0-7E6F1823AECB.mp4',
#   'original_filename': 'tmp_v4738285297174712779.mp4',
#   'path': '/Users/huohsien/Pictures/Photos Library.photoslibrary/originals/B/BD6F9E12-C36D-487B-A8C0-7E6F1823AECB.mp4',
#   'asset_scope': 'NORMAL_ORIGINALS',
#   'is_movie': True,
#   'date': '2019-10-23T13:13:07+08:00',
#   'date_added': '2019-11-24T21:37:36.063112+08:00',
#   'date_modified': None,
#   'description': None,
#   'keywords': ('HIDE',),
#   'favorite': False,
#   'hidden': False,
#   'hasadjustments': False,
#   'adjustment_type': 0,
#   'external_edit': False,
#   'uti_edited': None,
#   'path_edited': None,
#   'path_edited_live_photo': None,
#   'edited_duration_seconds': None,
#   'latitude': None,
#   'longitude': None,
#   'location': (None, None),
#   'place': None,
#   'is_live_photo': False,
#   'path_live_photo': None,
#   'albums': {'CBD8DBB1-E6A7-45D3-ADBE-88BB7C8FFE46': {'uuid': 'CBD8DBB1-E6A7-45D3-ADBE-88BB7C8FFE46',
#     'title': 'Sex Fun Clips - 情色打掃 奶子露出來漂亮',
#     'folders': {'1002E254-8A71-4586-967B-C9E8EEF38809': {'uuid': '1002E254-8A71-4586-967B-C9E8EEF38809',
#       'title': 'HIDE',
#       'path': 'HIDE'}}}},
#   'folders': {'1002E254-8A71-4586-967B-C9E8EEF38809': {'uuid': '1002E254-8A71-4586-967B-C9E8EEF38809',
#     'title': 'HIDE',
#     'path': 'HIDE'}}}]

# %%
# ============================================================
# Test 1: Check whether a proposed asset unique ID scheme is unique
# ============================================================

def check_photos_library_asset_unique_id_scheme(
    photos_library_path,
    max_duplicate_groups_to_print=20,
):
    # This function checks whether the proposed asset unique ID scheme is unique
    # inside one Photos Library.
    #
    # Proposed ID scheme:
    #   full original_filename
    #   + date converted to Asia/Taipei
    #   + year removed
    #   + keep month/day/hour/minute/second
    #
    # Example:
    #   IMG_0164.PNG + 11-28 13:18:00

    import osxphotos
    from collections import defaultdict
    from zoneinfo import ZoneInfo

    photosdb = osxphotos.PhotosDB(photos_library_path)
    assets = photosdb.photos()

    taipei_tz = ZoneInfo("Asia/Taipei")

    key_to_assets = defaultdict(list)
    assets_without_key = []

    for asset in assets:
        original_filename = asset.original_filename or asset.filename

        if original_filename is None or asset.date is None:
            assets_without_key.append(asset)
            continue

        # Normalize date/time to Asia/Taipei before removing the year.
        date_taipei = asset.date.astimezone(taipei_tz)

        no_year_datetime = (
            f"{date_taipei.month:02d}-"
            f"{date_taipei.day:02d} "
            f"{date_taipei.hour:02d}:"
            f"{date_taipei.minute:02d}:"
            f"{date_taipei.second:02d}."
            f"{date_taipei.microsecond:06d}"
)

        # Normalize date_added to Asia/Taipei and keep the full timestamp.
        date_added_taipei = asset.date_added.astimezone(taipei_tz)

        date_added_datetime = (
            f"{date_added_taipei.year:04d}-"
            f"{date_added_taipei.month:02d}-"
            f"{date_added_taipei.day:02d} "
            f"{date_added_taipei.hour:02d}:"
            f"{date_added_taipei.minute:02d}:"
            f"{date_added_taipei.second:02d}"
        )

        proposed_unique_id = (
            original_filename,
            no_year_datetime,
            date_added_datetime,
        )

        key_to_assets[proposed_unique_id].append(asset)

    duplicate_groups = {
        key: group
        for key, group in key_to_assets.items()
        if len(group) > 1
    }

    duplicate_asset_count = sum(len(group) for group in duplicate_groups.values())
    is_unique = len(duplicate_groups) == 0 and len(assets_without_key) == 0

    print("Photos Library:")
    print(photos_library_path)
    print("-" * 80)
    print("total asset count:", len(assets))
    print("generated unique ID count:", len(key_to_assets))
    print("assets without proposed unique ID:", len(assets_without_key))
    print("duplicate unique ID group count:", len(duplicate_groups))
    print("duplicate asset count:", duplicate_asset_count)
    print("is proposed unique ID scheme unique:", is_unique)

    if assets_without_key:
        print()
        print("Assets without proposed unique ID")
        print("-" * 80)

        for asset in assets_without_key[:max_duplicate_groups_to_print]:
            print("uuid:", asset.uuid)
            print("filename:", asset.filename)
            print("original_filename:", asset.original_filename)
            print("date:", asset.date)
            print("-" * 80)

    if duplicate_groups:
        print()
        print("Duplicate unique ID groups")
        print("-" * 80)

        for index, (key, group) in enumerate(duplicate_groups.items()):
            if index >= max_duplicate_groups_to_print:
                print("... more duplicate groups not printed")
                break

            print("proposed unique ID:", key)
            print("asset count:", len(group))

            for asset in group:
                print("  uuid:", asset.uuid)
                print("  filename:", asset.filename)
                print("  original_filename:", asset.original_filename)
                print("  date:", asset.date)
                print("  path:", asset.path)

            print("-" * 80)

    return is_unique

# %%
check_photos_library_asset_unique_id_scheme(PHOTOS_LIBRARY_PATHS["snapshot_20260603"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 check_photos_library_asset_unique_id_scheme(PHOTOS_LIBRARY_PATHS["snapshot_20260603"])
#
# KeyError: 'snapshot_20260603'

# %%
check_photos_library_asset_unique_id_scheme(PHOTOS_LIBRARY_PATHS["backup_20250317"])
